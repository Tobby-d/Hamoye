# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import csv

# %%
dataset = pd.read_csv('https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv')

# %%
dataset.head(10)
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
# 5  f1_fuel_1994_12_2_0_13                 2         1994
# 6   f1_fuel_1994_12_2_1_1                 2         1994
# 7  f1_fuel_1994_12_2_1_10                 2         1994
# 8  f1_fuel_1994_12_2_2_10                 2         1994
# 9   f1_fuel_1994_12_4_0_1                 4         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# ...

# %%
a = [1,2,3,4,5,6]
b = [13,21,34]
#best way to create a merged list is t0 use the extend method
a.extend(b)
print(a)
# Out:
# [1, 2, 3, 4, 5, 6, 13, 21, 34]

# %%
np.identity(3) #gives a 3 x 3 identity matrix using numpy
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
dataset['fuel_mmbtu_per_unit'].describe()
#.describe() gives basic statistical details
# Out:
# count    29523.000000
# mean         8.492111
# std         10.600220
# min          0.000001
# 25%          1.024000
# 50%          5.762694
# 75%         17.006000
# max        341.260000
# Name: fuel_mmbtu_per_unit, dtype: float64

# %%
#for skewness and kurtosis, we use .skew() and .kurt on the dataset
skewness = dataset['fuel_qty_burned'].skew()
kurtosis = dataset['fuel_qty_burned'].kurt()
print(skewness)
print(kurtosis)
# Out:
# 15.851495469109503
# 651.3694501337732

# %%
missing_values = dataset['fuel_unit'].isna()
if any(missing_values) == True:
  print('It has missing Values')
#categorical and mode imputation works well
# Out:
# It has missing Values

# %%
#we use the .corr() to check correlation with the fuel cost per unit burned
dataset.corr()
# Out:
#                               utility_id_ferc1  report_year  fuel_qty_burned  \
# utility_id_ferc1                      1.000000     0.093323        -0.057447
# report_year                           0.093323     1.000000         0.012952
# fuel_qty_burned                      -0.057447     0.012952         1.000000
# fuel_mmbtu_per_unit                  -0.066946    -0.110853        -0.080946
# fuel_cost_per_unit_burned            -0.037863     0.013599        -0.018535
# fuel_cost_per_unit_delivered         -0.016414    -0.014043        -0.003551
# fuel_cost_per_mmbtu                   0.006122     0.010261        -0.001896
#
#                               fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# utility_id_ferc1                        -0.066946                  -0.037863
# report_year                             -0.110853                   0.013599
# fuel_qty_burned                         -0.080946                  -0.018535
# ...

# %%
feature = dataset["fuel_unit"].isna().sum()
total = dataset["record_id"].count()
percentage_missing = (feature/total) * 100 
print(feature)
print(total)
print(percentage_missing)
# Out:
# 180
# 29523
# 0.609694136774718
